# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

# %%
columns = ['symboling','normalized-losses','make','fuel-type','aspiration','num-of-doors','body-style','drive-wheeels','engine-location','wheel-base','length','width','height','curb-weight','engine-type','num-of-cylinders','engine-size','fuel-system','bore','stroke','compression-ratio','horsepower','peak-rpm','city-mpg','highway-mpg','price']
cars = pd.read_csv('imports-85.data',names = columns)

# %%
cars.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheeels engine-location  wheel-base  ...  engine-size  \
# 0  convertible           rwd           front        88.6  ...          130
# 1  convertible           rwd           front        88.6  ...          130
# 2    hatchback           rwd           front        94.5  ...          152
# 3        sedan           fwd           front        99.8  ...          109
# 4        sedan           4wd           front        99.4  ...          136
#
# ...

# %%
numeric_columns = ['normalized-losses','wheel-base','length','width','height','curb-weight','engine-size','bore','stroke','compression-ratio','horsepower','peak-rpm','city-mpg','highway-mpg','price']

numeric_cars = cars[numeric_columns]

# %%
numeric_cars.head()
# Out:
#   normalized-losses  wheel-base  length  width  height  curb-weight  \
# 0                 ?        88.6   168.8   64.1    48.8         2548
# 1                 ?        88.6   168.8   64.1    48.8         2548
# 2                 ?        94.5   171.2   65.5    52.4         2823
# 3               164        99.8   176.6   66.2    54.3         2337
# 4               164        99.4   176.6   66.4    54.3         2824
#
#    engine-size  bore stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0          130  3.47   2.68                9.0        111     5000        21
# 1          130  3.47   2.68                9.0        111     5000        21
# 2          152  2.68   3.47                9.0        154     5000        19
# 3          109  3.19   3.40               10.0        102     5500        24
# 4          136  3.19   3.40                8.0        115     5500        18
#
#    highway-mpg  price
# 0           27  13495
# 1           27  16500
# 2           26  16500
# ...

# %%
numeric_cars = numeric_cars.replace('?', np.nan)

# %%
numeric_cars = numeric_cars.astype('float')
numeric_cars.isnull().sum()
# Out:
# normalized-losses    41
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-size           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
## predicting "price" column so need to get rid of the empty rows in the price column
numeric_cars = numeric_cars.dropna(subset = ['price'])
numeric_cars.isnull().sum()
# Out:
# normalized-losses    37
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-size           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
## replace other missing values with mean
numeric_cars = numeric_cars.fillna(numeric_cars.mean())

# %%
## normalize all columns except "price"
price_column = numeric_cars['price']
numeric_cars = (numeric_cars - numeric_cars.min())/(numeric_cars.max()-numeric_cars.min())
numeric_cars['price'] = price_column

# %%
numeric_cars.head()
# Out:
#    normalized-losses  wheel-base    length     width    height  curb-weight  \
# 0           0.298429    0.058309  0.413433  0.324786  0.083333     0.411171
# 1           0.298429    0.058309  0.413433  0.324786  0.083333     0.411171
# 2           0.298429    0.230321  0.449254  0.444444  0.383333     0.517843
# 3           0.518325    0.384840  0.529851  0.504274  0.541667     0.329325
# 4           0.518325    0.373178  0.529851  0.521368  0.541667     0.518231
#
#    engine-size      bore    stroke  compression-ratio  horsepower  peak-rpm  \
# 0     0.260377  0.664286  0.290476             0.1250    0.294393  0.346939
# 1     0.260377  0.664286  0.290476             0.1250    0.294393  0.346939
# 2     0.343396  0.100000  0.666667             0.1250    0.495327  0.346939
# 3     0.181132  0.464286  0.633333             0.1875    0.252336  0.551020
# 4     0.283019  0.464286  0.633333             0.0625    0.313084  0.551020
#
#    city-mpg  highway-mpg    price
# ...

# %%
def knn_train_test(training_column, target_column, df):
    knn = KNeighborsRegressor()
    np.random.seed(1)
    
    ## randomize data frame
    shuffled_index = np.random.permutation(df.index)
    df = df.reindex(shuffled_index)
    
    ## splitting the data frame to a training and test set
    last_row = int(len(df)/2)
    train_df = df.iloc[0:last_row]
    test_df = df.iloc[last_row:]
    
    ## fitting the model
    knn.fit(train_df[[training_column]], train_df[target_column])
    
    ## predictions on the test set
    predictions = knn.predict(test_df[[training_column]])
    
    ## calculate the rmse
    mse = mean_squared_error(predictions, test_df[target_column])
    rmse = mse**(1/2)
    return rmse

results = {}
train_columns = numeric_cars.columns.drop('price')

for i in train_columns:
    rmse_value = knn_train_test(i, 'price', numeric_cars)
    results[i] = rmse_value

rmse_series = pd.Series(results)
rmse_series.sort_values()
# Out:
# engine-size          3238.462830
# horsepower           4037.037713
# curb-weight          4401.118255
# highway-mpg          4630.026799
# width                4704.482590
# city-mpg             4766.422505
# length               5427.200961
# wheel-base           5461.553998
# compression-ratio    6610.812153
# bore                 6780.627785
# normalized-losses    7330.197653
# peak-rpm             7697.459696
# stroke               8006.529545
# height               8144.441043
# dtype: float64

# %%
## writing a new function to accept different k values
def knn_train_test(training_column, target_column, df):
    np.random.seed(1)
    
    ## randomize data frame
    shuffled_index = np.random.permutation(df.index)
    df = df.reindex(shuffled_index)
    
    ## splitting the data frame to a training and test set
    last_row = int(len(df)/2)
    train_df = df.iloc[0:last_row]
    test_df = df.iloc[last_row:]
    
    ## training the model and making predictions
    k_values = [1,3,5,7,9]
    rmse_values = {}
    
    for k in k_values:
        knn = KNeighborsRegressor(n_neighbors = k)
        knn.fit(train_df[[training_column]], train_df[target_column])
        
        predictions = knn.predict(test_df[[training_column]])
        
        mse = mean_squared_error(predictions, test_df[target_column])
        rmse = np.sqrt(mse)
        
        rmse_values[k] = rmse
    return rmse_values            
  
multiple_k_value_rmse = {}
training_columns = numeric_cars.columns.drop('price')

for i in training_columns:
    rmse_value = knn_train_test(i, 'price', numeric_cars)
    multiple_k_value_rmse[i] = rmse_value

print(multiple_k_value_rmse)
# Out:
# {'normalized-losses': {1: 7846.750605148984, 3: 7500.5698123109905, 5: 7330.197653434445, 7: 7756.421586234123, 9: 7688.096096891432}, 'wheel-base': {1: 4493.734068810494, 3: 5120.161506064513, 5: 5461.553997873057, 7: 5448.1070513823315, 9: 5738.405685192312}, 'length': {1: 4628.45550121557, 3: 5129.8358210721635, 5: 5427.2009608367125, 7: 5313.427720847974, 9: 5383.054514833446}, 'width': {1: 4559.257297950061, 3: 4606.413692169901, 5: 4704.482589704386, 7: 4571.485046194653, 9: 4652.914172067787}, 'height': {1: 8904.04645636071, 3: 8277.609643045525, 5: 8144.441042663747, 7: 7679.598124393773, 9: 7811.03606291223}, 'curb-weight': {1: 5264.290230758878, 3: 5022.318011757233, 5: 4401.118254793124, 7: 4330.608104418053, 9: 4632.044474454401}, 'engine-size': {1: 3258.4861059962027, 3: 2840.562805643501, 5: 3238.4628296477176, 7: 3563.086774256415, 9: 3831.8244149840766}, 'bore': {1: 8602.58848450066, 3: 6984.239489480916, 5: 6780.627784685976, 7: 6878.097965921532, 9: 6866.80850203841
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

for k,v in multiple_k_value_rmse.items():
    x = list(v.keys())
    y = list(v.values())
    
    plt.plot(x,y)
    plt.xlabel('K value')
    plt.ylabel('RMSE')
    
## We can see that the very best results are at a k value of 3

# %%
## determining the exact rmse value on average for each feature
feature_avg_rmse = {}
for k,v in multiple_k_value_rmse.items():
    avg_rmse = np.mean(list(v.values()))
    feature_avg_rmse[k] = avg_rmse
series_avg_rmse = pd.Series(feature_avg_rmse)
sorted_series_avg_rmse = series_avg_rmse.sort_values()
print(sorted_series_avg_rmse)

sorted_features = sorted_series_avg_rmse.index
# Out:
# engine-size          3346.484586
# horsepower           4219.377860
# width                4618.910560
# curb-weight          4730.075815
# highway-mpg          5069.469256
# length               5176.394904
# city-mpg             5202.409003
# wheel-base           5252.392462
# compression-ratio    7166.073599
# bore                 7222.472445
# normalized-losses    7624.407151
# stroke               8000.240467
# peak-rpm             8119.365233
# height               8163.346266
# dtype: float64

# %%
## changing the function to be trained on a list of columns
def knn_train_test(training_columns, target_column, df):
    np.random.seed(1)
    
    ## randomize rows
    shuffled_index = np.random.permutation(df.index)
    df = df.reindex(shuffled_index)
    
    ## splitting the data frame to a training and test set
    last_row = int(len(df)/2)
    train_df = df.iloc[0:last_row]
    test_df = df.iloc[last_row:]
    
    ## training the model and making predictions
    k_values = [5]
    rmse_values = {}
    
    for i in k_values:
        knn = KNeighborsRegressor(n_neighbors = k)
        knn.fit(train_df[training_columns],train_df[target_column])
        
        predictions = knn.predict(test_df[training_columns])
        
        mse = mean_squared_error(predictions, test_df[target_column])
        rmse = mse**(1/2)
        rmse_values[k] = rmse
    return rmse_values

## using the best features from the previous step to calculate rmse
multiple_columns_rmse_results = {}
for nr_best_feats in range(2,7):
    multiple_columns_rmse_results['{} best features'.format(nr_best_feats)] = knn_train_test(
        sorted_features[:nr_best_feats],'price',numeric_cars)

multiple_column_rmse_results
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-28ad69f36ff3> in <module>
#      30 multiple_columns_rmse_results = {}
#      31 for nr_best_feats in range(2,7):
# ---> 32     multiple_columns_rmse_results['{} best features'.format(nr_best_feats)] = knn_train_test(
#      33         sorted_features[:nr_best_feats],'price',numeric_cars)
#      34
#
# <ipython-input-40-28ad69f36ff3> in knn_train_test(training_columns, target_column, df)
#      18     for i in k_values:
#      19         knn = KNeighborsRegressor(n_neighbors = k)
# ---> 20         knn.fit(train_df[training_columns],train_df[target_column])
#      21
#      22         predictions = knn.predict(test_df[training_columns])
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in fit(self, X, y)
#    1108                                        multi_output=True)
#    1109         self._y = y
# ...
