# %%
import pandas as pd
loans = pd.read_csv('cleaned_credit_data')
loans = loans.drop(columns = ['Unnamed: 0'])
loans.head()
# Out:
#    loan_amnt        term int_rate  installment emp_length home_ownership  \
# 0     5000.0   36 months   10.65%       162.87  10+ years           RENT
# 1     2500.0   60 months   15.27%        59.83   < 1 year           RENT
# 2     2400.0   36 months   15.96%        84.33  10+ years           RENT
# 3    10000.0   36 months   13.49%       339.31  10+ years           RENT
# 4     5000.0   36 months    7.90%       156.46    3 years           RENT
#
#    annual_inc verification_status  loan_status         purpose  ...  \
# 0     24000.0            Verified            1     credit_card  ...
# 1     30000.0     Source Verified            0             car  ...
# 2     12252.0        Not Verified            1  small_business  ...
# 3     49200.0     Source Verified            1           other  ...
# 4     36000.0     Source Verified            1         wedding  ...
#
#   delinq_2yrs earliest_cr_line  inq_last_6mths  open_acc pub_rec  revol_bal  \
# ...

# %%
## determining the number of null values there are in the dataframe
null_counts = loans.isnull().sum()
print(null_counts[null_counts>0])
# Out:
# emp_length              1036
# title                     11
# revol_util                50
# last_credit_pull_d         2
# pub_rec_bankruptcies     697
# dtype: int64

# %%
## the two main columns with a lot of missing values is "emp_length" and "pub_rec_bankruptcies"
## we can assume emp_length will be a good indicator of if someone can pay back a loan or not so we will keep that column for sure
print(loans.pub_rec_bankruptcies.value_counts(normalize=True, dropna=False))
# Out:
# 0.0    0.939438
# 1.0    0.042456
# NaN    0.017978
# 2.0    0.000129
# Name: pub_rec_bankruptcies, dtype: float64

# %%
## since the majority of the values in "pub_rec_bankruptcies" are the same we can just get rid of that column
loans = loans.drop(columns = ['pub_rec_bankruptcies'])

# %%
## for the other missing values we will just get rid of the rows that have any missing values
loans = loans.dropna(axis = 0)
print(loans.dtypes.value_counts())
# Out:
# object     11
# float64    10
# int64       1
# dtype: int64

# %%
## the object types need to be converted to numerical values for ski-kit-learn
## first we will see what the different object values look like
object_columns_df = loans.select_dtypes(include=["object"])
object_columns_df.head()
# Out:
#          term int_rate emp_length home_ownership verification_status  \
# 0   36 months   10.65%  10+ years           RENT            Verified
# 1   60 months   15.27%   < 1 year           RENT     Source Verified
# 2   36 months   15.96%  10+ years           RENT        Not Verified
# 3   36 months   13.49%  10+ years           RENT     Source Verified
# 4   36 months    7.90%    3 years           RENT     Source Verified
#
#           purpose                                  title addr_state  \
# 0     credit_card                               Computer         AZ
# 1             car                                   bike         GA
# 2  small_business                   real estate business         IL
# 3           other                               personel         CA
# 4         wedding  My wedding loan I promise to pay back         AZ
#
#   earliest_cr_line revol_util last_credit_pull_d
# 0         Jan-1985      83.7%           Jun-2016
# ...

# %%
## only some of the columns contain categorical information
cols = ['home_ownership', 'verification_status', 'emp_length', 'term', 'addr_state']
for c in cols:
    print(loans[c].value_counts())
# Out:
# RENT        18112
# MORTGAGE    16686
# OWN          2778
# OTHER          96
# NONE            3
# Name: home_ownership, dtype: int64
# Not Verified       16281
# Verified           11856
# Source Verified     9538
# Name: verification_status, dtype: int64
# 10+ years    8545
# < 1 year     4513
# 2 years      4303
# 3 years      4022
# 4 years      3353
# 5 years      3202
# 1 year       3176
# 6 years      2177
# 7 years      1714
# 8 years      1442
# 9 years      1228
# Name: emp_length, dtype: int64
#  36 months    28234
#  60 months     9441
# Name: term, dtype: int64
# CA    6776
# NY    3614
# FL    2704
# TX    2613
# NJ    1776
# IL    1447
# PA    1442
# VA    1347
# GA    1323
# MA    1272
# OH    1149
# MD    1008
# AZ     807
# WA     788
# CO     748
# NC     729
# CT     711
# MI     678
# MO     648
# MN     581
# NV     466
# SC     454
# WI     427
# OR     422
# LA     420
# AL     420
# KY     311
# OK     285
# UT     249
# KS     249
# AR     229
# DC     209
# ...

# %%
## now looking at the "title" and "purpose" columns and their values
print(loans["title"].value_counts())
print(loans["purpose"].value_counts())
# Out:
# Debt Consolidation            2068
# Debt Consolidation Loan       1599
# Personal Loan                  624
# Consolidation                  488
# debt consolidation             466
#                               ...
# expense loan                     1
# For My Vacation                  1
# car and personal loan            1
# Home AC Units & Other debt       1
# Need Home improvement laod       1
# Name: title, Length: 18881, dtype: int64
# debt_consolidation    17751
# credit_card            4911
# other                  3711
# home_improvement       2808
# major_purchase         2083
# small_business         1719
# car                    1459
# wedding                 916
# medical                 655
# moving                  552
# house                   356
# vacation                348
# educational             312
# renewable_energy         94
# Name: purpose, dtype: int64

# %%
## we will change the 'emp_length' column with the numerical values listed in the mapping_dict
## we also are going to get rid of "last_credit_pull_d", "earliest_cr_line", "addr_state", "title" since their information is not very useful
mapping_dict = {
    "emp_length": {
        "10+ years": 10,
        "9 years": 9,
        "8 years": 8,
        "7 years": 7,
        "6 years": 6,
        "5 years": 5,
        "4 years": 4,
        "3 years": 3,
        "2 years": 2,
        "1 year": 1,
        "< 1 year": 0,
        "n/a": 0
    }
}
loans = loans.drop(["last_credit_pull_d", "earliest_cr_line", "addr_state", "title"], axis=1)
loans["int_rate"] = loans["int_rate"].str.rstrip("%").astype("float")
loans["revol_util"] = loans["revol_util"].str.rstrip("%").astype("float")
loans = loans.replace(mapping_dict)

# %%
## we now use dummy variables for the categorical columns so we can get numerical values for the model
cat_columns = ["home_ownership", "verification_status", "purpose", "term"]
dummy_df = pd.get_dummies(loans[cat_columns])
loans = pd.concat([loans, dummy_df], axis=1)
loans = loans.drop(cat_columns, axis=1)

# %%
loans.to_csv('cleaned_loans_2007')
